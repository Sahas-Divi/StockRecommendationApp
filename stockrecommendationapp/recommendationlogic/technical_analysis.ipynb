# %%
from langchain.agents import create_agent
import os
from dotenv import load_dotenv
from langchain_core.output_parsers import StrOutputParser
from langchain_openai import ChatOpenAI
from twelvedata import TDClient

load_dotenv()

openai_api_key = os.getenv("OPENAI_API_KEY")
twelve_data_api_key = os.getenv("TWELVE_DATA_API_KEY")
td = TDClient(apikey=twelve_data_api_key)
# Out:
# {'price': '307.39001'}

# %%
rsi_dict = {}

# %%
ticker_symbol = "APPL"

# %%
import requests

RSI_response = requests.get(f"https://api.twelvedata.com/rsi?symbol={ticker_symbol}&interval=1day&apikey={twelve_data_api_key}")


current_RSI = RSI_response.json()["values"][-1]

# %%
rsi_values = []

for i in range(5):
    rsi_values.append(float(RSI_response.json()["values"][i]['rsi']))

# %%
print(rsi_values)
# Out:
# [43.83642, 54.24632, 51.13961, 58.79015, 60.39106]

# %%
def calculate_rsi_trend(rsi_values):
    """
    rsi_values should be ordered newest -> oldest.
    Uses the most recent 5 RSI values.
    """

    if len(rsi_values) < 5:
        raise ValueError("Need at least 5 RSI values")

    current_rsi = rsi_values[0]
    rsi_5_days_ago = rsi_values[4]

    slope = (current_rsi - rsi_5_days_ago) / 4

    return slope

# %%
def classify_rsi_trend(slope):
    if slope > 1:
        return "strongly_rising"
    elif slope > 0.3:
        return "rising"
    elif slope < -1:
        return "strongly_falling"
    elif slope < -0.3:
        return "falling"
    else:
        return "flat"

# %%
slope = calculate_rsi_trend(rsi_values)

print(slope)

trend = classify_rsi_trend(-1.57)

print(trend)
# Out:
# -4.138660000000002
# strongly_falling

# %%
def classify_rsi_zone(current_rsi, rsi_trend):
    if current_rsi < 30 and rsi_trend == "rising":
        signal = "bullish"

    elif current_rsi > 70 and rsi_trend == "falling":
        signal = "bearish"

    else:
        signal = "neutral"

    return signal

# %%
rsi_zone = classify_rsi_zone(float(RSI_response.json()["values"][0]['rsi']), trend)

# %%
print(rsi_zone)
# Out:
# neutral

# %%
rsi_dict["current_RSI"] = float(RSI_response.json()["values"][0]['rsi'])
rsi_dict["rsi_trend"] = trend
rsi_dict["rsi_zone"] = rsi_zone

# %%
print(rsi_dict)
# Out:
# {'current_RSI': 43.83642, 'rsi_trend': 'strongly_falling', 'rsi_zone': 'neutral'}

# %%
moving_average_20 = requests.get(f"https://api.twelvedata.com/ma?symbol=AAPL&interval=1day&time_period=20&apikey={twelve_data_api_key}")
print(moving_average_20.json())
# Out:
# {'meta': {'symbol': 'AAPL', 'interval': '1day', 'currency': 'USD', 'exchange_timezone': 'America/New_York', 'exchange': 'NASDAQ', 'mic_code': 'XNGS', 'type': 'Common Stock', 'indicator': {'name': 'MA - Moving Average', 'series_type': 'close', 'time_period': 20, 'ma_type': 'SMA'}}, 'values': [{'datetime': '2026-06-05', 'ma': '304.25600'}, {'datetime': '2026-06-04', 'ma': '303.25850'}, {'datetime': '2026-06-03', 'ma': '302.072501'}, {'datetime': '2026-06-02', 'ma': '300.76850'}, {'datetime': '2026-06-01', 'ma': '298.85000'}, {'datetime': '2026-05-29', 'ma': '297.54150'}, {'datetime': '2026-05-28', 'ma': '295.50600'}, {'datetime': '2026-05-27', 'ma': '293.38900'}, {'datetime': '2026-05-26', 'ma': '291.38200'}, {'datetime': '2026-05-22', 'ma': '289.34600'}, {'datetime': '2026-05-21', 'ma': '287.45800'}, {'datetime': '2026-05-20', 'ma': '285.88000'}, {'datetime': '2026-05-19', 'ma': '284.42600'}, {'datetime': '2026-05-18', 'ma': '282.78600'}, {'datetime': '2026-05-15', 'ma': '281.54650'}, {'datetime': '2026-05-14', 'ma': '280.046500'}, {'datetime': '2026-05-13', 'ma': '278.30600'}, {'datetime': '2026-05-12', 'ma': '276.68400'}, {'datetime': '2026-05-11', 'ma': '274.88550'}, {'datetime': '2026-05-08', 'ma': '273.21150'}, {'datetime': '2026-05-07', 'ma': '271.56950'}, {'datetime': '2026-05-06', 'ma': '270.22200'}, {'datetime': '2026-05-05', 'ma': '268.79150'}, {'datetime': '2026-05-04', 'ma': '267.25750'}, {'datetime': '2026-05-01', 'ma': '266.35900'}, {'datetime': '2026-04-30', 'ma': '265.14800'}, {'datetime': '2026-04-29', 'ma': '264.36200'}, {'datetime': '2026-04-28', 'ma': '263.54300'}, {'datetime': '2026-04-27', 'ma': '262.33900'}, {'datetime': '2026-04-24', 'ma': '261.39850'}], 'status': 'ok'}

# %%
moving_average_50 = requests.get(f"https://api.twelvedata.com/ma?symbol=AAPL&interval=1day&time_period=50&apikey={twelve_data_api_key}")
print(moving_average_50.json())
# Out:
# {'meta': {'symbol': 'AAPL', 'interval': '1day', 'currency': 'USD', 'exchange_timezone': 'America/New_York', 'exchange': 'NASDAQ', 'mic_code': 'XNGS', 'type': 'Common Stock', 'indicator': {'name': 'MA - Moving Average', 'series_type': 'close', 'time_period': 50, 'ma_type': 'SMA'}}, 'values': [{'datetime': '2026-06-05', 'ma': '281.23840'}, {'datetime': '2026-06-04', 'ma': '280.14300'}, {'datetime': '2026-06-03', 'ma': '278.95120'}, {'datetime': '2026-06-02', 'ma': '277.77580'}, {'datetime': '2026-06-01', 'ma': '276.43160'}, {'datetime': '2026-05-29', 'ma': '275.28460'}, {'datetime': '2026-05-28', 'ma': '274.042200'}, {'datetime': '2026-05-27', 'ma': '272.87660'}, {'datetime': '2026-05-26', 'ma': '271.71600'}, {'datetime': '2026-05-22', 'ma': '270.55180'}, {'datetime': '2026-05-21', 'ma': '269.49060'}, {'datetime': '2026-05-20', 'ma': '268.60700'}, {'datetime': '2026-05-19', 'ma': '267.77860'}, {'datetime': '2026-05-18', 'ma': '266.99680'}, {'datetime': '2026-05-15', 'ma': '266.18920'}, {'datetime': '2026-05-14', 'ma': '265.39040'}, {'datetime': '2026-05-13', 'ma': '264.67660'}, {'datetime': '2026-05-12', 'ma': '263.97420'}, {'datetime': '2026-05-11', 'ma': '263.37260'}, {'datetime': '2026-05-08', 'ma': '262.80260'}, {'datetime': '2026-05-07', 'ma': '262.39520'}, {'datetime': '2026-05-06', 'ma': '262.13100'}, {'datetime': '2026-05-05', 'ma': '261.82360'}, {'datetime': '2026-05-04', 'ma': '261.46360'}, {'datetime': '2026-05-01', 'ma': '261.21860'}, {'datetime': '2026-04-30', 'ma': '260.82740'}, {'datetime': '2026-04-29', 'ma': '260.68740'}, {'datetime': '2026-04-28', 'ma': '260.56160'}, {'datetime': '2026-04-27', 'ma': '260.26300'}, {'datetime': '2026-04-24', 'ma': '260.14540'}], 'status': 'ok'}

# %%
moving_average_200 = requests.get(f"https://api.twelvedata.com/ma?symbol=AAPL&interval=1day&time_period=200&apikey={twelve_data_api_key}")
print(moving_average_200.json())
# Out:
# {'meta': {'symbol': 'AAPL', 'interval': '1day', 'currency': 'USD', 'exchange_timezone': 'America/New_York', 'exchange': 'NASDAQ', 'mic_code': 'XNGS', 'type': 'Common Stock', 'indicator': {'name': 'MA - Moving Average', 'series_type': 'close', 'time_period': 200, 'ma_type': 'SMA'}}, 'values': [{'datetime': '2026-06-05', 'ma': '265.19335'}, {'datetime': '2026-06-04', 'ma': '264.80920'}, {'datetime': '2026-06-03', 'ma': '264.40750'}, {'datetime': '2026-06-02', 'ma': '264.014149'}, {'datetime': '2026-06-01', 'ma': '263.60205'}, {'datetime': '2026-05-29', 'ma': '263.23715'}, {'datetime': '2026-05-28', 'ma': '262.82510'}, {'datetime': '2026-05-27', 'ma': '262.39845'}, {'datetime': '2026-05-26', 'ma': '261.99095'}, {'datetime': '2026-05-22', 'ma': '261.54945'}, {'datetime': '2026-05-21', 'ma': '261.071599'}, {'datetime': '2026-05-20', 'ma': '260.56125'}, {'datetime': '2026-05-19', 'ma': '260.066749'}, {'datetime': '2026-05-18', 'ma': '259.58380'}, {'datetime': '2026-05-15', 'ma': '259.13245'}, {'datetime': '2026-05-14', 'ma': '258.67655'}, {'datetime': '2026-05-13', 'ma': '258.24185'}, {'datetime': '2026-05-12', 'ma': '257.81775'}, {'datetime': '2026-05-11', 'ma': '257.41315'}, {'datetime': '2026-05-08', 'ma': '257.018549'}, {'datetime': '2026-05-07', 'ma': '256.62270'}, {'datetime': '2026-05-06', 'ma': '256.25750'}, {'datetime': '2026-05-05', 'ma': '255.88235'}, {'datetime': '2026-05-04', 'ma': '255.51735'}, {'datetime': '2026-05-01', 'ma': '255.18330'}, {'datetime': '2026-04-30', 'ma': '254.83340'}, {'datetime': '2026-04-29', 'ma': '254.52220'}, {'datetime': '2026-04-28', 'ma': '254.21445'}, {'datetime': '2026-04-27', 'ma': '253.91670'}, {'datetime': '2026-04-24', 'ma': '253.64070'}], 'status': 'ok'}

# %%
current_price = td.price(symbol="AAPL").as_json()

# %%
print(current_price)
# Out:
# {'price': '307.39001'}

# %%
ma_dict = {}

# %%
ma20 = float(moving_average_20.json()["values"][0]["ma"])
ma50 = float(moving_average_50.json()["values"][0]["ma"])
ma200 = float(moving_average_200.json()["values"][0]["ma"])
price = float(current_price["price"])

# %%
print("ma20: ",ma20)
print("ma50: ",ma50)
print("ma200: ",ma200)
print("price: ",price)
# Out:
# ma20:  304.256
# ma50:  281.2384
# ma200:  265.19335
# price:  307.39001

# %%
price_above_ma20 = price > ma20
price_above_ma50 = price > ma50
price_above_ma200 = price > ma200

# %%
ma_dict["price_above_ma20"]=price_above_ma20
ma_dict["price_above_ma50"]=price_above_ma50
ma_dict["price_above_ma200"]=price_above_ma200

# %%
print(ma_dict)
# Out:
# {'price_above_ma20': True, 'price_above_ma50': True, 'price_above_ma200': True}

# %%
def ma_alignment_classification(ma20, ma50, ma200):
    if ma20 > ma50 > ma200:
        alignment = "bullish"
    elif ma20 < ma50 < ma200:
        alignment = "bearish"
    else:
        alignment = "mixed"

    return alignment

# %%
ma_dict["alignment"] = ma_alignment_classification(ma20, ma50, ma200)

# %%
print(ma_dict["alignment"])
# Out:
# bullish

# %%
ma20_values = moving_average_20.json()["values"]
current_ma20 = float(ma20_values[0]["ma"])
past_ma20 = float(ma20_values[4]["ma"])
ma20_slope = (current_ma20 - past_ma20) / 4
if ma20_slope > 0:
    ma20_trend = "rising"
elif ma20_slope < 0:
    ma20_trend = "falling"
else:
    ma20_trend = "flat"

# %%
print(ma20_trend)
# Out:
# rising

# %%
ma50_values = moving_average_50.json()["values"]
current_ma50 = float(ma50_values[0]["ma"])
past_ma50 = float(ma50_values[4]["ma"])
ma50_slope = (current_ma50 - past_ma50) / 4
if ma50_slope > 0:
    ma50_trend = "rising"
elif ma50_slope < 0:
    ma50_trend = "falling"
else:
    ma50_trend = "flat"

print(ma50_trend)
# Out:
# rising

# %%
ma200_values = moving_average_200.json()["values"]
current_ma200 = float(ma200_values[0]["ma"])
past_ma200 = float(ma200_values[4]["ma"])
ma200_slope = (current_ma200 - past_ma200) / 4
if ma200_slope > 0:
    ma200_trend = "rising"
elif ma200_slope < 0:
    ma200_trend = "falling"
else:
    ma200_trend = "flat"

print(ma200_trend)
# Out:
# rising

# %%
pct_above_ma20 = ((price - ma20) / ma20) * 100
pct_above_ma50 = ((price - ma50) / ma50) * 100
pct_above_ma200 = ((price - ma200) / ma200) * 100

# %%
ma50_values = moving_average_50.json()["values"]
ma200_values = moving_average_200.json()["values"]

current_ma50 = float(ma50_values[0]["ma"])
previous_ma50 = float(ma50_values[1]["ma"])

current_ma200 = float(ma200_values[0]["ma"])
previous_ma200 = float(ma200_values[1]["ma"])

golden_cross_today = (
    current_ma50 > current_ma200 and
    previous_ma50 <= previous_ma200
)

death_cross_today = (
    current_ma50 < current_ma200 and
    previous_ma50 >= previous_ma200
)

# %%
print(ma_dict)
# Out:
# {'price_above_ma20': True, 'price_above_ma50': True, 'price_above_ma200': True, 'alignment': 'bullish'}

# %%
ma_dict["pct_above_ma20"] = round(((price - ma20) / ma20) * 100, 2)
ma_dict["pct_above_ma50"] = round(((price - ma50) / ma50) * 100, 2)
ma_dict["pct_above_ma200"] = round(((price - ma200) / ma200) * 100, 2)

ma_dict["ma20_trend"] = ma20_trend
ma_dict["ma50_trend"] = ma50_trend
ma_dict["ma200_trend"] = ma200_trend

ma_dict["ma20_slope"] = round(ma20_slope, 3)
ma_dict["ma50_slope"] = round(ma50_slope, 3)
ma_dict["ma200_slope"] = round(ma200_slope, 3)

ma_dict["golden_cross"] = golden_cross_today

# %%
print(ma_dict)
# Out:
# {'price_above_ma20': True, 'price_above_ma50': True, 'price_above_ma200': True, 'alignment': 'bullish', 'pct_above_ma20': 1.03, 'pct_above_ma50': 9.3, 'pct_above_ma200': 15.91, 'ma20_trend': 'rising', 'ma50_trend': 'rising', 'ma200_trend': 'rising', 'ma20_slope': 1.351, 'ma50_slope': 1.202, 'ma200_slope': 0.398}
